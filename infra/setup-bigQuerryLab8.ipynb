# %%
from google.cloud import bigquery

project_id = "ai-dj-487610"
dataset_id = "all_stocks_5yr"

client = bigquery.Client(project=project_id)

dataset = bigquery.Dataset(f"{project_id}.{dataset_id}")
dataset.location = "europe-west1"

# Use exists_ok=True to make this command safe to run multiple times
dataset = client.create_dataset(dataset, exists_ok=True)
print(f"Created dataset {dataset.project}.{dataset.dataset_id}")
# Out:
# Created dataset ai-dj-487610.all_stocks_5yr

# %%
import pandas as pd

df = pd.read_csv("all_stocks_5yr.csv")

table_id = f"{project_id}.{dataset_id}.all_stocks_5yr"
job = client.load_table_from_dataframe(df, table_id)
job.result()

print(f"Loaded {len(df)} rows into {table_id}")
# Out:
# c:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:486: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# Loaded 619040 rows into ai-dj-487610.all_stocks_5yr.all_stocks_5yr

# %%
# !pip install google-cloud-bigquery pandas db-dtypes
# Out:
# Requirement already satisfied: google-cloud-bigquery in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.40.1)
# Requirement already satisfied: pandas in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.2)
# Requirement already satisfied: db-dtypes in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.5.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.1 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (2.29.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-bigquery) (2.48.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-bigquery) (2.8.0)
# Requirement already satisfied: packaging>=24.2.0 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-cloud-bigquery) (2.32.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.27.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.78.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (4.9.1)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.0.0 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery) (1.8.0)
# Requirement already satisfied: typing-extensions~=4.12 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (4.15.0)
# Requirement already satisfied: six>=1.5 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.6.2)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pyarrow>=13.0.0 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from db-dtypes) (23.0.1)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (2.23)

# %%
from google.cloud import bigquery

client = bigquery.Client()

query = """
SELECT *
FROM `ai-dj-487610.all_stocks_5yr.all_stocks_5yr`
"""

df = client.query(query).to_dataframe()
# Out:
# c:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1238080 entries, 0 to 1238079
# Data columns (total 7 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   date    1238080 non-null  object
#  1   open    1238058 non-null  float64
#  2   high    1238064 non-null  float64
#  3   low     1238064 non-null  float64
#  4   close   1238080 non-null  float64
#  5   volume  1238080 non-null  Int64
#  6   Name    1238080 non-null  object
# dtypes: Int64(1), float64(4), object(2)
# memory usage: 67.3+ MB

# %%
from google.cloud import bigquery

project_id = "ai-dj-487610"
dataset_id = "housing"

client = bigquery.Client(project=project_id)

dataset = bigquery.Dataset(f"{project_id}.{dataset_id}")
dataset.location = "europe-west1"

# Use exists_ok=True to make this command safe to run multiple times
dataset = client.create_dataset(dataset, exists_ok=True)
print(f"Created dataset {dataset.project}.{dataset.dataset_id}")
# Out:
# Created dataset ai-dj-487610.housing

# %%
import pandas as pd

df = pd.read_csv("housing.csv")

table_id = f"{project_id}.{dataset_id}.housing"
job = client.load_table_from_dataframe(df, table_id)
job.result()

print(f"Loaded {len(df)} rows into {table_id}")
# Out:
# c:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:486: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# Loaded 20640 rows into ai-dj-487610.housing.housing

# %%
from google.cloud import bigquery

client = bigquery.Client()

query = """
SELECT *
FROM `ai-dj-487610.housing.housing`
"""

df = client.query(query).to_dataframe()
# Out:
# c:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  Int64
#  3   total_rooms         20640 non-null  Int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  Int64
#  6   households          20640 non-null  Int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  Int64
# dtypes: Int64(5), float64(4), object(1)
# memory usage: 1.7+ MB

# %%
from google.cloud import bigquery

project_id = "ai-dj-487610"
dataset_id = "iris"

client = bigquery.Client(project=project_id)

dataset = bigquery.Dataset(f"{project_id}.{dataset_id}")
dataset.location = "europe-west1"

# Use exists_ok=True to make this command safe to run multiple times
dataset = client.create_dataset(dataset, exists_ok=True)
print(f"Created dataset {dataset.project}.{dataset.dataset_id}")
# Out:
# Created dataset ai-dj-487610.iris

# %%
import pandas as pd

df = pd.read_csv("iris.csv")

table_id = f"{project_id}.{dataset_id}.iris"
job = client.load_table_from_dataframe(df, table_id)
job.result()

print(f"Loaded {len(df)} rows into {table_id}")
# Out:
# c:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:486: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# Loaded 150 rows into ai-dj-487610.iris.iris

# %%
from google.cloud import bigquery

client = bigquery.Client()

query = """
SELECT *
FROM `ai-dj-487610.iris.iris`
"""

df = client.query(query).to_dataframe()
# Out:
# c:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    Int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: Int64(1), float64(4), object(1)
# memory usage: 7.3+ KB

# %%
from google.cloud import bigquery

project_id = "ai-dj-487610"
dataset_id = "winequality_red"

client = bigquery.Client(project=project_id)

dataset = bigquery.Dataset(f"{project_id}.{dataset_id}")
dataset.location = "europe-west1"

# Use exists_ok=True to make this command safe to run multiple times
dataset = client.create_dataset(dataset, exists_ok=True)
print(f"Created dataset {dataset.project}.{dataset.dataset_id}")
# Out:
# Created dataset ai-dj-487610.winequality_red

# %%
import pandas as pd

df = pd.read_csv("winequality-red.csv")

table_id = f"{project_id}.{dataset_id}.winequality_red"
job = client.load_table_from_dataframe(df, table_id)
job.result()

print(f"Loaded {len(df)} rows into {table_id}")
# Out:
# c:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:486: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# Loaded 1599 rows into ai-dj-487610.winequality_red.winequality_red

# %%
from google.cloud import bigquery

client = bigquery.Client()

query = """
SELECT *
FROM `ai-dj-487610.winequality_red.winequality_red`
"""

df = client.query(query).to_dataframe()
# Out:
# c:\Users\antoi\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   Int64
# dtypes: Int64(1), float64(11)
# memory usage: 151.6 KB
